# %%
## Complete this as homework
a, r, n = 2, 3, 3
count = 1
term = a
while count <=n :
    print(f"{count}th term is {term}")

    term = term*r
    count+=1
# Out:
# 1th term is 2
# 2th term is 6
# 3th term is 18

# %% [markdown]
# | line | count | term | count <=n | print(term) |
# | :--: | :---: |:---: |  :---:    | :---:       |
# |  5-6 |   1   |  2   |    T      |  2          |
# |   8  |       |  6   |           |             |
# |   9  |   2   |      |           |             |
# |  5-6 |       |      |    T      |   6         |
# |   8  |       |  18  |           |             |
# |   9  |   3   |      |           |             |
# |  5-6 |       |      |    T      |   18        |
# |   8  |       |  54  |           |             |
# |   9  |   4   |      |           |             |
# |   5  |       |      |    F      |             |

# %%
a, r, n = 2, 3, 3
term = a
count = 1
while True:
    if count > n:
        break
    print(term)
    term = term*r
    count +=1

# %% [markdown]
# | line | count | term | count > n | print(term) |
# | ---  | :---: |:---: |  :---:    | :---        |
# | 5-7  | 1     | 2    | F         |    2         |
# | 8    |       | 6    |                        |
# | 9    | 2     |      |           |             |
# | 5-7  |       |      | F         |    6        |
# | 8    |       |  18  |                        |
# | 9    | 3     |      |                        |
# | 5-7  |       |      | F         |     18     |
# | 8    |       |  54  |           |            |
# | 9    |  4    |      |           |            |
# | 5    |       |      |  T        |            |
