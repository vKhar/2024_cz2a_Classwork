# %%
f = open("STUDENTS1.csv")
lines = f.readlines()
data = []
for line in lines[1:]:
    data.append(line.strip().split(","))

# %%
data

# %%
f = open("STUDENTS2.csv")
lines = f.readlines()
data = []
for i in range(0,len(lines),5):
    record = []
    for j in range(5):
        line = lines[i+j].strip()
        record.append(line)
    data.append(record)

# %%
f = open("STUDENTS2.csv")
data = []
lines = f.read()
lines = lines.split("\n")
for i in range(0,len(lines),5):
   data.append(lines[i:i+5])

# %%
data

# %%
f = open("STUDENTS3.csv")
lines = f.readlines()
for line in lines[1:]:
    print( line.strip().split(",") )

# %%
import csv
csv_reader = csv.reader(open("STUDENTS3.csv"))
data = []
for record in list(csv_reader)[1:]:
    data.append(record)

# %%
data
