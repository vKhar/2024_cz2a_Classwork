# %% [markdown]
# Task 1.1: 2.5
#
# Task 1.2: 1
#
# Task 1.3: 0
#
# Task 1.4: 0
#
# Total: 3.5

# %%
#Task 1.1
class Student3H2GP():
    #[0.5]implement h2_grade_table as attribute
    h2grade_table = {'A':20, 'B':17.5,'C':15,'D':12.5,'E':10,'S':5,'U':0}
    UAS = 0

    def __repr():
        constructor(student_id,h2grades,gp_grade)

    def compute_UAS():
        #[0]did not access self.__h2 grade table to compute UAS
        #[1]correct computation of UAS
        if h2grades[0] == 'A':
            UAS += 20
        elif h2grades[0] == 'B':
            UAS += 17.5
        elif h2grades[0] == 'C':
            UAS += 15
        elif h2grades[0] == 'D':
            UAS += 12.5
        elif h2grades[0] == 'E':
            UAS += 10
        elif h2grades[0] == 'S':
            UAS += 5
        else:
            UAS += 0

        if h2grades[1] == 'A':
            UAS += 20
        elif h2grades[1] == 'B':
            UAS += 17.5
        elif h2grades[1] == 'C':
            UAS += 15
        elif h2grades[1] == 'D':
            UAS += 12.5
        elif h2grades[1] == 'E':
            UAS += 10
        elif h2grades[1] == 'S':
            UAS += 5
        else:
            UAS += 0

        if h2grades[2] == 'A':
            UAS += 20
        elif h2grades[2] == 'B':
            UAS += 17.5
        elif h2grades[2] == 'C':
            UAS += 15
        elif h2grades[2] == 'D':
            UAS += 12.5
        elif h2grades[2] == 'E':
            UAS += 10
        elif h2grades[2] == 'S':
            UAS += 5
        else:
            UAS += 0

        if gp_grade == 'A':
            UAS += 10
        elif gp_grade == 'B':
            UAS += 8.75
        elif gp_grade == 'C':
            UAS += 7.5
        elif gp_grade == 'D':
            UAS += 6.25
        elif gp_grade == 'E':
            UAS += 5
        elif gp_grade == 'S':
            UAS += 2.5
        else:
            UAS += 0

#[1]initialised AND print object
# wrong way to initialise object
print(Student3H2GP(constructor(student_id:'1001',h2grades:['A','B','C'],GP:'B'))

# %%
#Task 1.2

class Student3H2GP_MT(Student3H2GP):
    UAS = 0
    def __repr__():
        constructor(student_id,h2grades,gp_grade,mt_grade)

    def compute_UAS():
        #[0] did not call super() to access parent's compute_uas and h2gradetable
        if h2grades[0] == 'A':
            UAS += 20
        elif h2grades[0] == 'B':
            UAS += 17.5
        elif h2grades[0] == 'C':
            UAS += 15
        elif h2grades[0] == 'D':
            UAS += 12.5
        elif h2grades[0] == 'E':
            UAS += 10
        elif h2grades[0] == 'S':
            UAS += 5
        else:
            UAS += 0

        if h2grades[1] == 'A':
            UAS += 20
        elif h2grades[1] == 'B':
            UAS += 17.5
        elif h2grades[1] == 'C':
            UAS += 15
        elif h2grades[1] == 'D':
            UAS += 12.5
        elif h2grades[1] == 'E':
            UAS += 10
        elif h2grades[1] == 'S':
            UAS += 5
        else:
            UAS += 0

        if h2grades[2] == 'A':
            UAS += 20
        elif h2grades[2] == 'B':
            UAS += 17.5
        elif h2grades[2] == 'C':
            UAS += 15
        elif h2grades[2] == 'D':
            UAS += 12.5
        elif h2grades[2] == 'E':
            UAS += 10
        elif h2grades[2] == 'S':
            UAS += 5
        else:
            UAS += 0

        if gp_grade == 'A':
            UAS += 10
        elif gp_grade == 'B':
            UAS += 8.75
        elif gp_grade == 'C':
            UAS += 7.5
        elif gp_grade == 'D':
            UAS += 6.25
        elif gp_grade == 'E':
            UAS += 5
        elif gp_grade == 'S':
            UAS += 2.5
        else:
            UAS += 0

        if gp_grade == 'A':
            UAS += 10
        elif gp_grade == 'B':
            UAS += 8.75
        elif gp_grade == 'C':
            UAS += 7.5
        elif gp_grade == 'D':
            UAS += 6.25
        elif gp_grade == 'E':
            UAS += 5
        elif gp_grade == 'S':
            UAS += 2.5
        else:
            UAS += 0

        if mt_grade == 'A':
            UAS += 10
        elif mt_grade == 'B':
            UAS += 8.75
        elif mt_grade == 'C':
            UAS += 7.5
        elif mt_grade == 'D':
            UAS += 6.25
        elif mt_grade == 'E':
            UAS += 5
        elif mt_grade == 'S':
            UAS += 2.5
        else:
            UAS += 0

        #[1]rebase
        UAS = UAS * 7/8

print(compute_UAS())

print(Student3H2GP_MT)

# %%
#Task 1.3

class Student3H2GP_H1content(Student3H2GP):
    UAS = 0
    def __repr__():
        constructor(student_id,h2grades,gp_grade,h1_contentgrade)

    def compute_UAS():
        #[0] did not call super() to access parent's compute_uas and h2gradetable and rebase
        if h2grades[0] == 'A':
            UAS += 20
        elif h2grades[0] == 'B':
            UAS += 17.5
        elif h2grades[0] == 'C':
            UAS += 15
        elif h2grades[0] == 'D':
            UAS += 12.5
        elif h2grades[0] == 'E':
            UAS += 10
        elif h2grades[0] == 'S':
            UAS += 5
        else:
            UAS += 0

        if h2grades[1] == 'A':
            UAS += 20
        elif h2grades[1] == 'B':
            UAS += 17.5
        elif h2grades[1] == 'C':
            UAS += 15
        elif h2grades[1] == 'D':
            UAS += 12.5
        elif h2grades[1] == 'E':
            UAS += 10
        elif h2grades[1] == 'S':
            UAS += 5
        else:
            UAS += 0

        if h2grades[2] == 'A':
            UAS += 20
        elif h2grades[2] == 'B':
            UAS += 17.5
        elif h2grades[2] == 'C':
            UAS += 15
        elif h2grades[2] == 'D':
            UAS += 12.5
        elif h2grades[2] == 'E':
            UAS += 10
        elif h2grades[2] == 'S':
            UAS += 5
        else:
            UAS += 0

        if gp_grade == 'A':
            UAS += 10
        elif gp_grade == 'B':
            UAS += 8.75
        elif gp_grade == 'C':
            UAS += 7.5
        elif gp_grade == 'D':
            UAS += 6.25
        elif gp_grade == 'E':
            UAS += 5
        elif gp_grade == 'S':
            UAS += 2.5
        else:
            UAS += 0

        if gp_grade == 'A':
            UAS += 10
        elif gp_grade == 'B':
            UAS += 8.75
        elif gp_grade == 'C':
            UAS += 7.5
        elif gp_grade == 'D':
            UAS += 6.25
        elif gp_grade == 'E':
            UAS += 5
        elif gp_grade == 'S':
            UAS += 2.5
        else:
            UAS += 0

        if h1_contentgrade == 'A':
            UAS += 10
        elif h1_contentgrade == 'B':
            UAS += 8.75
        elif mt_grade == 'C':
            UAS += 7.5
        elif mt_grade == 'D':
            UAS += 6.25
        elif mt_grade == 'E':
            UAS += 5
        elif mt_grade == 'S':
            UAS += 2.5
        else:
            UAS += 0

        UAS = UAS * 7/8
