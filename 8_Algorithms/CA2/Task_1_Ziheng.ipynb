# %% [markdown]
# Task 1.1: 6
#
# Task 1.2: 1
#
# Task 1.3: 0
#
# Task 1.4: 0
#
# Total: 7

# %%
#Task 1.1
class Student3H2GP:
    def __init__ (self,student_id,h2grades,gp_grade):
        self.__student_id = student_id #[1]indicate private attribute by using __
        self.__h2grades = h2grades
        self.__gp_grade = gp_grade
        #[1]implement h2_grade_table as attribute and get_h2grade_table() function

    def __repr__ (self):
        return f"{student_id},{h2grades},{gp_grade}"

    def get_student_id(self):#[3] getter and setter pairs
        return self.__student_id
    def set_student_id(self):
        return self.__student_id

    def get_h2grades(self):
        return self.__h2grades
    def set_h2grades(self):
        return self.__h2grades

    def get_gp_grade(self):
        return self.__gp_grade
    def set_gp_grade(self):
        return self.__gp_grade

    def __repr__(student_id,h2grades,gp_grade): #[1]return correct string
        return f"{get_student_id},list(get_h2grades).{gp.grade}"

    #test
    student_id = "1001"
    h2grades = ["A","B","c"]
    gp_grade = "B"
    print(student_id,h2grades,gp_grade)
    #[0] did not initialise AND print object
# Out:
# 1001 ['A', 'B', 'c'] B

# %%
# Task 1.2
class Student3H2GP_MT(Student3H2GP):
    def __init__(self,mt_grade):
        #[1]call super() to initialise
        super.__init__(student_id,h2grades,gp_grade,mt_grade)

    def __repr__(self):
        return

# %%
# Task 1.3
# [-1] wrong super class, Student3H2GP_MT_H1content should be a subclass of Student3H2GP
class Student3H2GP_MT_H1content(Student3H2GP_MT):
    def __init__(self,h1content_grade):
        #[1]call super() to initialise
        super.__init__(student_id,h2grades,gp_grade,mt_grade,h1content_grade)

    def __repr__(self):
        return

# %%
# Task 1.4
class Student(Student3H2GP_MT):
