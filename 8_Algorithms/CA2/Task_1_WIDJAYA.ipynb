# %% [markdown]
# Task 1.1: 5
#
# Task 1.2: 4
#
# Task 1.3: 4
#
# Task 1.4: 1
#
# Total: 14

# %%
class Student3H2GP:
    #[1]implement h2_grade_table as attribute and get_h2grade_table() function
    h2grade_table = {
        'A': 20,
        'B': 17.5,
        'C': 15,
        'D': 12.5,
        'E': 10,
        'S': 5,
        'U': 0
    }
    def __init__(self, student_id:str, h2grades:list, gp_grade:str):
        #[1]indicate private attribute by using __
        self.__student_id = student_id
        self.__h2grades = h2grades
        self.__gp_grade = gp_grade

    def get_student_id(self):
        return self.__student_id

    def get_h2grades(self):
        return self.__h2grades

    def get_gp_grade(self):
        return self.__gp_grade

    def get_h2grade_table():
        return h2grade_table

    def set_student_id(self, student_id):
        self.__student_id = student_id

    def set_h2grades(self, h2grades):
        self.__h2grades = h2grades

    def set_gp_grade(self, gp_grade):
        self.__gp_grade = gp_grade

    def compute_uas(self):
        #[0]access self.__h2 grade table to compute UAS
        # access h2 grades using self.__h2grades
        # access h2grade_table by using self.h2grade_table or Student3H2GP.h2grade_table
        # because you declared it as a class variable
        #[1]correct computation of UAS
        h2_score = 0
        gp_score = 0
        for grade in self.__h2grades():
            h2_score += h2grade_table[grade]
        gp_score = 1/2 * h2grade_table[self.__gp_grade]
        total_score = h2_score + gp_score
        return total_score


    #[1]return correct string
    def __repr__(self):
        return f"{self.__student_id}, 3H2: {self.__h2grades}, GP: {self.__gp_grade}"


#[1]initialised AND print object
alevel = Student3H2GP('1001', ['A', 'B', 'C'],  'B')
print(alevel)
print(alevel.set_student_id)
# Out:
# 1001, 3H2: ['A', 'B', 'C'], GP: B
# <bound method Student3H2GP.set_student_id of 1001, 3H2: ['A', 'B', 'C'], GP: B>

# %%
class Student3H2GP_MT(Student3H2GP):
    def __init__(self, student_id:str, h2grades:list, gp_grade:str, mt_grade:str):
        #[0] did not call super() to initialise
        self.__student_id = student_id
        self.__h2grades = h2grades
        self.__gp_grade = gp_grade
        #i forgot how super() works right now but im pretty sure this works
        #[1]indicate private attribute by using __
        self.__mt_grade = mt_grade

    def __repr__(self):#[0] did not use super().__repr__()
        return f"{self.__student_id}, 3H2: {self.__h2grades}, GP: {self.__gp_grade}, MT: {self.__mt_grade}"

    def get_mt_grade(self):#[1]getter and setter pair
        return mt_grade

    def set_mt_grade(self, mt_grade):
        self.__mt_grade = mt_grade

    def compute_uas():
        #[0] did not call super() to access parent's compute_uas and h2gradetable
        h2_score = 0
        gp_score = 0
        mt_score = 0
        for grade in self.__h2grades():
            h2_score += h2grade_table[grade]
        gp_score = 1/2 * h2grade_table[self.__gp_grade]
        mt_score = 1/2 * h2grade_table[self.__mt_grade]
        #[1]rebase
        total_score = (h2_score + gp_score + mt_score) * 7/8
        return total_score

#[1] initialize and print object
alevel = Student3H2GP_MT('1002', ['A', 'B', 'C'], 'B', 'C')
print(alevel)
#[0] did not test compute_uas
# Out:
# 1002, 3H2: ['A', 'B', 'C'], GP: B, MT: C

# %%
class Student3H2GP_MT_H1content(Student3H2GP):
    def __init__(self, student_id:str, h2grades:list, gp_grade:str, mt_grade:str, h1content_grade:str):
        #[0] did not call super() to initialise
        self.__student_id = student_id
        self.__h2grades = h2grades
        self.__gp_grade = gp_grade
        #i forgot how super() works right now but im pretty sure this works
        #[1] ( either here or in Student3H2GP_MT_H1content class )
               #indicate private attribute by using __
        self.__mt_grade = mt_grade
        self.__h1content_grade = h1content_grade

    #[0] did not use super().__repr__()
    def __repr__(self):
        return f"{self.__student_id}, 3H2: {self.__h2grades}, GP: {self.__gp_grade}, MT: {self.__mt_grade}, H1 Content: {self.__h1content_grade}"

    def get_mt_grade(self):#[2]getter and setter pairs
        return self.__mt_grade

    def set_mt_grade(self, mt_grade):
        self.__mt_grade = mt_grade

    def get_h1content_grade(self):
        return self.__h1content_grade

    def set_h1conetnt_grade(self, h1content_grade):
        self.__h1content_grade = h1content_grade

    def compute_uas(self):
        #[0] did not call super() to access parent's compute_uas and h2gradetable and rebase
        h2_score = 0
        gp_score = 0
        mt_score = 0
        h1_score = 0
        for grade in self.__h2grades():
            h2_score += h2grade_table[grade]
        gp_score = 1/2 * h2grade_table[self.__gp_grade]
        mt_score = 1/2 * h2grade_table[self.__mt_grade]
        h1_score = 1/2 * h2grade_table[self.__h1content_grade]

        total_score = (h2_score + gp_score + mt_score) * 7/9
        return total_score

class Student3H2GP_H1content(Student3H2GP):
     def __init__(self, student_id:str, h2grades:list, gp_grade:str, h1content_grade:str):
        #[0] did not call super() to initialise
        self.__student_id = student_id
        self.__h2grades = h2grades
        self.__gp_grade = gp_grade
        #i forgot how super() works right now but im pretty sure this works
        self.__h1content_grade = h1content_grade

    def compute_uas(self):
        #[0] did not call super() to access parent's compute_uas and h2gradetable and rebase
        h2_score = 0
        gp_score = 0
        h1_score = 0
        for grade in self.__h2grades():
            h2_score += h2grade_table[grade]
        gp_score = 1/2 * h2grade_table[self.__gp_grade]
        h1_score = 1/2 * h2grade_table[self.__h1content_grade]

        total_score = (h2_score + gp_score + mt_score) * 7/8
        return total_score

    def get_h1content_grade(self):#[1]getter and setter pair
        return self.__h1content_grade

    def set_h1conetnt_grade(self, h1content_grade):
        self.__h1content_grade = h1content_grade

    #[0] did not use super().__repr__()
    def __repr__(self):
        return f"{self.__student_id}, 3H2: {self.__h2grades}, GP: {self.__gp_grade}, H1 Content: {self.__h1content_grade}"

# %%
class Student:
    #[1] correct constructor and initialisation
    def __init__(self, student_id:str, h2grades:list, gp_grade:str, mt_grade:str, h1content_grade:str):
        self.__student_id = student_id
        self.__h2grades = h2grades
        self.__gp_grade = gp_grade
        #i forgot how super() works right now but im pretty sure this works
        # no super to call because Student is not a subclass of the above classes
        self.__mt_grade = mt_grade
        self.__h1content_grade = h1content_grade

    def compute_max_uas(self): #[0]
        student_uas1 = Student3H2GP()

# %%
help()
# Out:
# Welcome to Python 3.6's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at http://docs.python.org/3.6/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> dict
# Help on class dict in module builtins:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
# ...
