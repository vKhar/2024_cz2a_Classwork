# %% [markdown]
# Task 1.1: 8
#
# Task 1.2: 5
#
# Task 1.3: 4
#
# Task 1.4: 2
#
# Total: 19

# %%
#Task 1.1
class Student3H2GP:

    def __init__(self, student_id : str , h2grades : list, gp_grade : str,  h2grade_table = {
            "A" : 20,
            "B" : 17.5,
            "C" : 15,
            "D" : 12.5,
            "E" : 10,
            "S" : 5,
            "U" : 0 } ):
        #[1]indicate private attribute by using __        
        self.__h2grades = h2grades
        self.__GP = gp_grade
        self.__student_id = student_id
        #[1]implement h2_grade_table as attribute and get_h2grade_table() function

    def get_student_id(self):#[3] getter and setter pairs
        return self.__student_id
    def set_student_id(student_id):
        self.__student_id = student_id
    def get_h2grades(self):
        return self.__h2grades
    def set_h2grades(h2grades):
        self.__h2grades = h2grades
    def get_gp_grade(self):
        return self.__gp_grade
    def set_gp_grade(gp_grade):
        self.__gp_grade = gp_grade
    def get_h2grade_table(self):
        h2grade_table = {
            "A" : 20,
            "B" : 17.5,
            "C" : 15,
            "D" : 12.5,
            "E" : 10,
            "S" : 5,
            "U" : 0
        }
        return h2grade_table
    def compute_uas(self):
        #[0]access self.__h2 grade table to compute UAS
        #[1]correct computation of UAS
        h2grade_table = {
            "A" : 20,
            "B" : 17.5,
            "C" : 15,
            "D" : 12.5,
            "E" : 10,
            "S" : 5,
            "U" : 0
        }
        uas = 0
        for grade in self.__h2grades:
            uas += h2grade_table[grade]
        uas += h2grade_table[self.__GP]/2
        return uas
    def __repr__(self):
        #[1]return correct string
        return f"student_id: {self.__student_id}, 3H2: {self.__h2grades}, GP: {self.__GP}."

#[1]initialised AND print object
student1001 = Student3H2GP("1001", ["A", "B", "C"], "B")
print(student1001)
# Out:
# student_id: 1001, 3H2: ['A', 'B', 'C'], GP: B.

# %%
#Task 1.2
class Student3H2GP_MT(Student3H2GP):
    def __init__(self, student_id, h2grades, gp_grade, mt_grade):
        #[0] did not call super() to initialise
        self.__student_id = student_id
        self.__h2grades = h2grades
        self.__gp_grade = gp_grade
        #[1]indicate private attribute by using __
        self.__mt_grade = mt_grade
        super().__init__(self, student_id, h2grades, gp_grade)
    def get_mt_grade(self): #[1]getter and setter pair
        return self.__mt_grade
    def set_mt_grade(self, grade):
        self.__mt_grade = grade
    def __repr__(self):
        #[0] did not use super().__repr__()
        return f"student_id: {self.__student_id}, 3H2: {self.__h2grades}, GP: {self.__gp_grade}, MT: {self.__mt_grade})"
    def compute_uas(self):
        #[0] did not call super() to access parent's compute_uas and h2gradetable
        h2grade_table = {
            "A" : 20,
            "B" : 17.5,
            "C" : 15,
            "D" : 12.5,
            "E" : 10,
            "S" : 5,
            "U" : 0
        }
        uas = 0
        for grade in self.__h2grades:
            uas += h2grade_table[grade]
        uas += h2grade_table[self.__gp_grade]/2
        uas += h2grade_table[self.__mt_grade]/2
        #[1]rebase
        uas = uas/8*7
        return uas
    
#[1] initialize and print object
student1001 = Student3H2GP_MT("1001", ["A", "B", "C"], "B", "C")
print(student1001)
#[1]test compute_uas
student1001.compute_uas()
# Out:
# student_id: 1001, 3H2: ['A', 'B', 'C'], GP: B, MT: C)
# 60.15625

# %%
#Task 1.3
class Student3H2GP_H1content(Student3H2GP):
    def __init__(self, student_id, h2grades, gp_grade, h1content_grade):
        #[0] did not call super() to initialise
        #[1] ( either here or in Student3H2GP_MT_H1content class )
               #indicate private attribute by using __
        self.__student_id = student_id
        self.__h2grades = h2grades
        self.__gp_grade = gp_grade
        self.__h1content_grade = h1content_grade
        super().__init__(self, student_id, h2grades, gp_grade)
    
    #[1]getter and setter pair
    def get_h1content_grade(self):
        return self.__h1content_grade
    def set_h1content_grade(self, grade):
        self.__h1content_grade = grade
    #[0] did not use super().__repr__()
    def __repr__(self):
        return f"student_id: {self.__student_id}, 3H2: {self.__h2grades}, GP: {self.__gp_grade}, H1: {self.__h1content_grade})"
    def compute_uas(self):
        #[0] did not call super() to access parent's compute_uas and h2gradetable and rebase
        h2grade_table = {
            "A" : 20,
            "B" : 17.5,
            "C" : 15,
            "D" : 12.5,
            "E" : 10,
            "S" : 5,
            "U" : 0
        }
        uas = 0
        for grade in self.__h2grades:
            uas += h2grade_table[grade]
        uas += h2grade_table[self.__gp_grade]/2
        uas += h2grade_table[self.__h1content_grade]/2
        uas = uas/8*7
        return uas
student1001 = Student3H2GP_H1content("1001", ["A", "B", "C"], "B", "C")
print(student1001)
student1001.compute_uas()
class Student3H2GP_MT_H1content(Student3H2GP):
    def __init__(self, student_id, h2grades, gp_grade, mt_grade, h1content_grade):
        #[0] did not call super() to initialise
        self.__student_id = student_id
        self.__h2grades = h2grades
        self.__gp_grade = gp_grade
        self.__mt_grade = mt_grade
        self.__h1content_grade = h1content_grade
        super().__init__(self, student_id, h2grades, gp_grade)
    
    #[2]getter and setter pairs
    def get_h1content_grade(self):
        return self.__h1content_grade
    def get_mt_grade(self):
        return self.__mt_grade
    def set_h1content_grade(self, grade):
        self.__h1content_grade = grade
    def set_mt_grade(self, grade):
        self.__mt_grade = grade
    def __repr__(self):
    #[0] did not use super().__repr__()
        return f"student_id: {self.__student_id}, 3H2: {self.__h2grades}, GP: {self.__gp_grade}, MT: {self.__mt_grade}, H1: {self.__h1content_grade})"
    
    def compute_uas(self):
        #[0] did not call super() to access parent's compute_uas and h2gradetable and rebase
        h2grade_table = {
            "A" : 20,
            "B" : 17.5,
            "C" : 15,
            "D" : 12.5,
            "E" : 10,
            "S" : 5,
            "U" : 0
        }
        uas = 0
        for grade in self.__h2grades:
            uas += h2grade_table[grade]
        uas += h2grade_table[self.__gp_grade]/2
        uas += h2grade_table[self.__mt_grade]/2
        uas += h2grade_table[self.__h1content_grade]/2
        uas = uas/9*7
        return uas
# Out:
# student_id: 1001, 3H2: ['A', 'B', 'C'], GP: B, H1: C)
# student_id: 1001, 3H2: ['A', 'B', 'C'], GP: B, MT: C, H1: A)
# 61.25

# %%
#Task 1.4
class Student():
    #[1] correct constructor and initialisation
    def __init__(self, student_id, h2_grades, gp_grade, mt_grade, h1content_grade):
        self.__student_id = student_id
        self.__h2grades = h2_grades
        self.__gp_grade = gp_grade
        self.__mt_grade = mt_grade
        self.__h1content_grade = h1content_grade   
    def compute_max_uas(self):
        #[0] did not initialise any of the 4 student classes' objects from above.
        # your method doesn't return anything
        h2grade_table = {
            "A" : 20,
            "B" : 17.5,
            "C" : 15,
            "D" : 12.5,
            "E" : 10,
            "S" : 5,
            "U" : 0
        }
        uas = 0
        for grade in self.__h2grades:
            uas += h2grade_table[grade]
        if uas/7 < (h2grade_table[self.__mt_grade] + h2grade_table[self.__h1content_grade])/4:
            uas += (h2grade_table[self.__mt_grade] + h2grade_table[self.__h1content_grade])/2
            uas = uas/9*7
        elif uas/7 < h2grade_table[self.__mt_grade]/2:
            uas += h2grade_table[self.__mt_grade]
            uas = uas/8*7
        elif uas/7 < h2grade_table[self.__h1content_gradde]/2:
            uas += h2grade_table[self.__h1content_grade]
            uas = uas/8*7

#[1]instantiate Student Object    
student1001 = Student("1001", ["A", "B", "C"], "B", "C", "A")
#[0] did not compute max UAS correctly
student1001.compute_max_uas()
