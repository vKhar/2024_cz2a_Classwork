# %% [markdown]
# Task 1.1: 7
#
# Task 1.2: 3
#
# Task 1.3: 4
#
# Task 1.4: 0
#
# Total: 14

# %%
#Task 1.1
class Student3H2GP():
    def __init__(self, student_id, h2grades, gp_grade):
        self.__studID = student_id #[1]indicate private attribute by using __
        self.__h2 = h2grades
        self.__gp = gp_grade
        #[0] did not implement h2_grade_table as attribute and get_h2grade_table() function

    # the constructor function refers to __init__()
    def constructor(self):
        return (f"student_id: {self.__studID}, h2grades: {self.__h2}, gp_grade: {self.__gp}")
    
    #[1]return correct string
    def __repr__(self):
        return (f"{self.__studID}, 3H2: {self.__h2}, GP: {self.__gp}")
    
    #[3] getter and setter pairs
    #setter
    def set_studID(self, new_student_id): #set_student_id
        self.__studID = new_student_id
    def set_h2(self, new_h2grades):
        self.__h2 = new_h2grades
    def set_gp(self, new_gp_grade):
        self.__gp = new_gp_grade
    #getter
    def get_studID(self):
        return self.__studID
    def get_h2(self):
        return self.__h2
    def get_gp(self):
        return self.__gp
    #compute
    def compute_uas(self):
        #[0] did not access self.__h2 grade table to compute UAS
        #[1] correct computation of UAS
        uas = 0
        for h2 in self.__h2:
            if h2 == "A":
                uas += 20
            if h2 == "B":
                uas += 17.5
            if h2 == "C":
                uas += 15
            if h2 == "D":
                uas += 12.5
            if h2 == "E":
                uas += 10
            if h2 == "S":
                uas += 5
            if h2 == "U":
                uas += 0
        if self.__gp == "A":
            uas += 20*0.5
        if self.__gp == "B":
            uas += 17.5*0.5
        if self.__gp == "C":
            uas += 15*0.5
        if self.__gp == "D":
            uas += 12.5*0.5
        if self.__gp == "E":
            uas += 10*0.5
        if self.__gp == "S":
            uas += 5*0.5
        if self.__gp == "U":
            uas += 0
        return uas

# %%
#Task 1.1
#[1]initialise AND print
print(Student3H2GP('1001',['A','B','C'],'B'))
# Out:
# 1001, 3H2: ['A', 'B', 'C'], GP: B

# %%
#Task 1.2
# [-1] did not inherit from Student3H2GP class  
class Student3H2GP_MT(): 
    def __init__(self, student_id, h2grades, gp_grade, mt_grade):
        #[0] did not call super() to initialise
        self.__studID = student_id
        self.__h2 = h2grades
        self.__gp = gp_grade
        #[1]indicate private attribute by using __
        self.__mt = mt_grade
    def constructor(self):
        return (f"student_id: {self.__studID}, h2grades: {self.__h2}, gp_grade: {self.__gp}, mt_grade: {self.__mt})")
    #[0] did not use super().__repr__()
    def __repr__(self):
        return (f"{self.__studID}, 3H2: {self.__h2}, GP: {self.__gp}, MT: {self.__mt}")
    #setter
    def set_studID(self, new_student_id): #set_student_id
        self.__studID = new_student_id
    def set_h2(self, new_h2grades):
        self.__h2 = new_h2grades
    def set_gp(self, new_gp_grade):
        self.__gp = new_gp_grade
    #[1]getter and setter
    def set_mt(self, new_mt_grade): 
        self.__mt = new_mt_grade
    #getter
    def get_studID(self):
        return self.__studID
    def get_h2(self):
        return self.__h2
    def get_gp(self):
        return self.__gp
    def get_mt(self):
        return self.__mt
    #compute
    def compute_uas(self):
        #[0] did not call super() to access parent's compute_uas and h2gradetable
        uas = 0
        for h2 in self.__h2:
            if h2 == "A":
                uas += 20
            if h2 == "B":
                uas += 17.5
            if h2 == "C":
                uas += 15
            if h2 == "D":
                uas += 12.5
            if h2 == "E":
                uas += 10
            if h2 == "S":
                uas += 5
            if h2 == "U":
                uas += 0
        if self.__gp == "A":
            uas += 20*0.5
        if self.__gp == "B":
            uas += 17.5*0.5
        if self.__gp == "C":
            uas += 15*0.5
        if self.__gp == "D":
            uas += 12.5*0.5
        if self.__gp == "E":
            uas += 10*0.5
        if self.__gp == "S":
            uas += 5*0.5
        if self.__gp == "U":
            uas += 0
        if self.__mt == "A":
            uas += 20*0.5
        if self.__mt == "B":
            uas += 17.5*0.5
        if self.__mt == "C":
            uas += 15*0.5
        if self.__mt == "D":
            uas += 12.5*0.5
        if self.__mt == "E":
            uas += 10*0.5
        if self.__mt == "S":
            uas += 5*0.5
        if self.__mt == "U":
            uas += 0
        #[1]rebase
        uas = uas*(7/8)
        return uas

# %%
#Task 1.2
#[0] initialized but did not print object
#[1]test compute_uas
Student3H2GP_MT('1001',['A','B','C'],'B','C').compute_uas()
Student3H2GP_MT('1001',['A','B','C'],'B','C')
# Out:
# 60.15625

# %%
#Task 1.3
class Student3H2GP_H1content():
    def __init__(self, student_id, h2grades, gp_grade, h1_grade):
        #[0] did not call super() to initialise
        self.__studID = student_id
        self.__h2 = h2grades
        self.__gp = gp_grade
        #[1] ( either here or in Student3H2GP_MT_H1content class )
               #indicate private attribute by using __
        self.__h1 = h1_grade
    def constructor(self):
        return (f"student_id: {self.__studID}, h2grades: {self.__h2}, gp_grade: {self.__gp}, h1_grade: {self.__h1})")
    #[0] did not use super().__repr__()
    def __repr__(self):
        return (f"{self.__studID}, 3H2: {self.__h2}, GP: {self.__gp}, H1: {self.__h1}")
    #setter
    def set_studID(self, new_student_id): #set_student_id
        self.__studID = new_student_id
    def set_h2(self, new_h2grades):
        self.__h2 = new_h2grades
    def set_gp(self, new_gp_grade):
        self.__gp = new_gp_grade
    def set_h1(self, new_h1_grade):#[1]getter and setter
        self.__h1 = new_h1_grade
    #getter
    def get_studID(self):
        return self.__studID
    def get_h2(self):
        return self.__h2
    def get_gp(self):
        return self.__gp
    def get_h1(self):
        return self.__h1
    #compute
    def compute_uas(self):
        #[0] did not call super() to access parent's compute_uas and h2gradetable and rebase
        uas = 0
        for h2 in self.__h2:
            if h2 == "A":
                uas += 20
            if h2 == "B":
                uas += 17.5
            if h2 == "C":
                uas += 15
            if h2 == "D":
                uas += 12.5
            if h2 == "E":
                uas += 10
            if h2 == "S":
                uas += 5
            if h2 == "U":
                uas += 0
        if self.__gp == "A":
            uas += 20*0.5
        if self.__gp == "B":
            uas += 17.5*0.5
        if self.__gp == "C":
            uas += 15*0.5
        if self.__gp == "D":
            uas += 12.5*0.5
        if self.__gp == "E":
            uas += 10*0.5
        if self.__gp == "S":
            uas += 5*0.5
        if self.__gp == "U":
            uas += 0
        if self.__h1 == "A":
            uas += 20*0.5
        if self.__h1 == "B":
            uas += 17.5*0.5
        if self.__h1 == "C":
            uas += 15*0.5
        if self.__h1 == "D":
            uas += 12.5*0.5
        if self.__h1 == "E":
            uas += 10*0.5
        if self.__h1 == "S":
            uas += 5*0.5
        if self.__h1 == "U":
            uas += 0
        uas = uas*(7/8)
        return uas

# %%
#Task 1.3
# wrong name, stated wrongly as name of Task 1.2
class Student3H2GP_MT():
    def __init__(self, student_id, h2grades, gp_grade, mt_grade, h1_grade):
        #[0] did not call super() to initialise
        self.__studID = student_id
        self.__h2 = h2grades
        self.__gp = gp_grade
        self.__mt = mt_grade
        self.__h1 = h1_grade
    def constructor(self):
        return (f"student_id: {self.__studID}, h2grades: {self.__h2}, gp_grade: {self.__gp}, mt_grade: {self.__mt}, h1_grade: {self.__h1}")
    #[0] did not use super().__repr__()
    def __repr__(self):
        return (f"{self.__studID}, 3H2: {self.__h2}, GP: {self.__gp}, MT: {self.__mt}, H1: {self.__h1}")
    #setter
    def set_studID(self, new_student_id): #set_student_id
        self.__studID = new_student_id
    def set_h2(self, new_h2grades):
        self.__h2 = new_h2grades
    def set_gp(self, new_gp_grade):
        self.__gp = new_gp_grade
    def set_mt(self, new_mt_grade):#[2]getter and setter pairs
        self.__mt = new_mt_grade
    def set_h1(self, new_h1_grade):
        self.__h1 = new_h1_grade
    #getter
    def get_studID(self):
        return self.__studID
    def get_h2(self):
        return self.__h2
    def get_gp(self):
        return self.__gp
    def get_mt(self):
        return self.__mt
    def get_mt(self):
        return self.__h1
    #compute
    def compute_uas(self):
        #[0] did not call super() to access parent's compute_uas and h2gradetable and rebase
        uas = 0
        for h2 in self.__h2:
            if h2 == "A":
                uas += 20
            if h2 == "B":
                uas += 17.5
            if h2 == "C":
                uas += 15
            if h2 == "D":
                uas += 12.5
            if h2 == "E":
                uas += 10
            if h2 == "S":
                uas += 5
            if h2 == "U":
                uas += 0
        if self.__gp == "A":
            uas += 20*0.5
        if self.__gp == "B":
            uas += 17.5*0.5
        if self.__gp == "C":
            uas += 15*0.5
        if self.__gp == "D":
            uas += 12.5*0.5
        if self.__gp == "E":
            uas += 10*0.5
        if self.__gp == "S":
            uas += 5*0.5
        if self.__gp == "U":
            uas += 0
        if self.__mt == "A":
            uas += 20*0.5
        if self.__mt == "B":
            uas += 17.5*0.5
        if self.__mt == "C":
            uas += 15*0.5
        if self.__mt == "D":
            uas += 12.5*0.5
        if self.__mt == "E":
            uas += 10*0.5
        if self.__mt == "S":
            uas += 5*0.5
        if self.__mt == "U":
            uas += 0
        if self.__gp == "A":
            uas += 20*0.5
        if self.__gp == "B":
            uas += 17.5*0.5
        if self.__gp == "C":
            uas += 15*0.5
        if self.__gp == "D":
            uas += 12.5*0.5
        if self.__gp == "E":
            uas += 10*0.5
        if self.__gp == "S":
            uas += 5*0.5
        if self.__gp == "U":
            uas += 0
        if self.__h1 == "A":
            uas += 20*0.5
        if self.__h1 == "B":
            uas += 17.5*0.5
        if self.__h1 == "C":
            uas += 15*0.5
        if self.__h1 == "D":
            uas += 12.5*0.5
        if self.__h1 == "E":
            uas += 10*0.5
        if self.__h1 == "S":
            uas += 5*0.5
        if self.__h1 == "U":
            uas += 0
        uas = uas*(7/9)
        return uas

# %%
# did not implement Student class
