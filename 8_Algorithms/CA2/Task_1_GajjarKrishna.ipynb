# %% [markdown]
# Task 1.1: 9
#
# Task 1.2: 9
#
# Task 1.3: 10
#
# Task 1.4: 6
#
# Total: 34

# %%
#Task 1.1
class Student3H2GP:
    def __init__(self, student_id, h2grades, gp_grade):
        #[1]indicate private attribute by using __
        #[1]dictionary and get_h2grade_table() function
        self.__h2grade_table = {"A":20, "B":17.5, "C":15, "D":12.5, "E":10, "S":5, "U":0}
        self.__student_id = student_id
        self.__h2grades = h2grades
        self.__gp_grade = gp_grade

    def __repr__(self):#[1]return correct string
        return f"{self.__student_id}, 3H2: {self.__h2grades}, GP: {self.__gp_grade}"

    def get_student_id(self):#[1] getter and setter pair
        return self.__student_id
    def set_student_id(self, student_id):
        self.__student_id = student_id

    def get_h2grades(self):#[1] getter and setter pair
        return self.__h2grades
    def set_h2grades(self, h2grades):
        self.__h2grades = h2grades

    def get_gp_grade(self):#[1] getter and setter pair
        return self.__gp_grade
    def set_gp_grade(self, gp_grade):
        self.__gp_grade = gp_grade

    def get_h2grade_table(self):
        return self.__h2grade_table

    def compute_uas(self):
        #[1]access self.__h2 grade table to compute UAS
        #[1]correct computation of UAS
        score = 0
        for grade in self.__h2grades:
            score += self.__h2grade_table[grade]
        score += (self.__h2grade_table[self.__gp_grade])*0.5
        return score

#[1]initialise AND print
print(Student3H2GP('1001', ['A','B','C'], 'B'))
# Out:
# 1001, 3H2: ['A', 'B', 'C'], GP: B

# %%
#Task 1.2
class Student3H2GP_MT(Student3H2GP):
    def __init__(self, student_id, h2_grades, gp_grade, mt_grade):
        #[1]call super() to initialise
        super().__init__(student_id, h2_grades, gp_grade)
        self.__h2grade_table = super().get_h2grade_table()
        #[1]indicate private attribute by using __
        self.__mt_grade = mt_grade

    def __repr__(self):#[1] use super().__repr__()
        return super().__repr__() + f", MT:{self.__mt_grade}"

    def get_mt_grade(self):#[1]getter and setter
        return self.__mt_grade
    def set_mt_grade(self, mt_grade):
        self.__mt_grade = mt_grade

    def compute_uas(self):
        #[2] call super() to access parent's compute_uas and h2gradetable
        h2GP_uas = super().compute_uas()
        score = (h2GP_uas + (0.5*(self.__h2grade_table[self.__mt_grade]))) * (7/8) #[1]rebase
        return score

#[1] initialize and print
#[1]test compute_uas
student1 = Student3H2GP_MT('1001',['A','B','C'],'B','C')
print(student1.compute_uas())
print(student1)
# Out:
# 60.15625
# 1001, 3H2: ['A', 'B', 'C'], GP: B, MT:C

# %%
#Task 1.3
class Student3H2GP_H1content(Student3H2GP):
    def __init__(self, student_id, h2_grades, gp_grade, h1content_grade):
        #[1]call super() to initialise
        super().__init__(student_id, h2_grades, gp_grade)
        #[1] ( either here or in Student3H2GP_MT_H1content class )
               #indicate private attribute by using __
        self.__h2grade_table = super().get_h2grade_table()
        self.__h1content_grade = h1content_grade

    def __repr__(self): #[1] use super().__repr__()
        return super().__repr__() + f", H1 Content:{self.__h1content_grade}"

    def get_h1content_grade(self): #[1]getter and setter
        return self.__h1content_grade
    def set_h1content_grade(self, h1content_grade):
        self.__h1content_grade = h1content_grade

    def compute_uas(self):
        #[1] call super() to access parent's compute_uas and h2gradetable and rebase
        h2GP_uas = super().compute_uas()
        score = (h2GP_uas + (0.5*(self.__h2grade_table[self.__h1content_grade]))) * (7/8)
        return score


class Student3H2GP_MT_H1content(Student3H2GP):
    def __init__(self, student_id, h2_grades, gp_grade, mt_grade, h1content_grade):
        super().__init__(student_id, h2_grades, gp_grade) #[1]call super() to initialise
        self.__h2grade_table = super().get_h2grade_table()
        self.__mt_grade = mt_grade
        self.__h1content_grade = h1content_grade

    def __repr__(self):#[1] use super().__repr__()
        return super().__repr__() + f", MT:{self.__mt_grade}" + f", H1 Content:{self.__h1content_grade}"

    def get_mt_grade(self):#[1]getter and setter
        return self.__mt_grade
    def set_mt_grade(self, mt_grade):
        self.__mt_grade = mt_grade

    def get_h1content_grade(self):#[1]getter and setter
        return self.__h1content_grade
    def set_h1content_grade(self, h1content_grade):
        self.__h1content_grade = h1content_grade

    def compute_uas(self):
        #[1] call super() to access parent's compute_uas and h2gradetable and rebase
        h2GP_uas = super().compute_uas()
        score = (h2GP_uas + (0.5*(self.__h2grade_table[self.__h1content_grade])) + (0.5*(self.__h2grade_table[self.__mt_grade]))) * (7/9)
        return score

# %%
#Task1.4
class Student:
    #[1] correct constructor
    def __init__(self, student_id, h2_grades, gp_grade, mt_grade, h1content_grade):
        self.__student_id = student_id
        self.__h2_grades = h2_grades
        self.__gp_grade = gp_grade
        self.__mt_grade = mt_grade
        self.__h1content_grade = h1content_grade

    def compute_max_uas(self):
        #[1]initialise any 2, [1] add one more mark if all 4 types of students initialised
        score1 = Student3H2GP(self.__student_id, self.__h2_grades, self.__gp_grade).compute_uas()
        score2 = Student3H2GP_MT(self.__student_id, self.__h2_grades, self.__gp_grade, self.__mt_grade).compute_uas()
        score3 = Student3H2GP_H1content(self.__student_id, self.__h2_grades, self.__gp_grade, self.__h1content_grade).compute_uas()
        score4 = Student3H2GP_MT_H1content(self.__student_id, self.__h2_grades, self.__gp_grade, self.__mt_grade, self.__h1content_grade).compute_uas()
        #[1]return max of 4 scores
        return max([score1, score2, score3, score4])

student = Student('1001',['A','B','C'],'B','C','A')#[1]instantiate Student Object
print(student.compute_max_uas())#[1] compute max UAS correctly
# Out:
# 62.34375
