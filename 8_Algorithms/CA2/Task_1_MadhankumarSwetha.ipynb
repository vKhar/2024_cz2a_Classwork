# %% [markdown]
# Task 1.1: 4.5
#
# Task 1.2: 2
#
# Task 1.3: 3
#
# Task 1.4: 1
#
# Total: 10.5

# %%
#Check for theory
ef calc(n):
    if n == 0:
        return 10
    else:
        return 2 + calc(n-1)
func(3)
# Out:
# 16

# %%
#Task 1.1

class Student3H2GP():
    def __init__(self,student_id,h2grades,gp_grade,h2grade_table):
        #[0] should indicate private attribute by using __ instead of _
        self._student_id = student_id
        self._h2grades = h2grades
        self._gp_grade = gp_grade
        #[0.5]implement h2_grade_table as attribute
        self._h2grade_table = h2grade_table

    def get_student_id(self): #[3] getter and setter pairs
        return (self._student_id)

    def set_student_id(self,student_id):
        self._student_id = student_id

    def get_h2grades(self):
        return (self._h2grades)

    def set_h2grades(self,h2grades):
        self._h2_grades = h2grades

    def get_gp_grade(self,gp_grade):
        return (self._gp_grade)

    def set_gp_grade(self,gp_grade):
        self._gp_grade = gp_grade

    # [0] did not implement get_h2grade_table() function correctly
    def get_h2grade_table(self):  #dict
        grades_dict = {'3H2': ' '
                      'GP': ' '
                      'MT': ''}
        for i in h2_grades:
            grades_dict.append(h2grades[i])

        if grades_dict == '3H2':
            grades.dict.append(self._h2grades)

        else: #grades_dict == 'GP':
            grades.dict.append(self._gp_grade)

        return grades_dict

    def compute_uas(self):
        #[0] did not access self.__h2 grade table to compute UAS
        #[0] incorrect computation of UAS, did not consider GP
        grades = 0
        for i in self._h2grades:
            if h2grades[i] == 'A':
                grades = grades + 20

            elif self._h2grades[i] == 'B':
                grades = grades + 17.5

            elif self._h2grades[i] == 'C':
                grades = grades + 15

            elif self._h2grades[i] == 'D':
                grades = grades + 12.5

            elif self._h2grades[i] == 'E':
                grades = grades + 10

            elif self._h2grades[i] == 'S':
                grades = grades + 5

            else: #self._h2grades[i] == U
                grades = grades + 0

        return grades

    #[1]return correct string
    def __repr__(self):
        f"<{self._student_id}>, 3H2: <{self._h2_grades}>, GP: <{self._gp_grade}>, MT: <{self._h2grade_table}>"
    #[0] did not initialise AND print object


        #Task 1.2
        # Student3H2GP_MT is a subclass of Student3H2GP, you did not indicate this relationship
    class Student3H2GP_MT():
        #[0] did not call super() to initialise
        def __init__(self):
            #[0] did not indicate private attribute by using __
            self._mt_grade = mt_grade

        def get_mt_grade(self): #[1]getter and setter
            return (self._mt_grade)

        def set_mt_grade(self,mt_grade):
            self._mt_grade = mt_grade

        def compute_uas(self):
            #[0] did not call super() to access parent's compute_uas and h2gradetable
            grades = 0

            for i in self._h2grades:
                if h2grades[i] == 'A':
                    grades = grades + 20

                elif self._h2grades[i] == 'B':
                    grades = grades + 17.5

                elif self._h2grades[i] == 'C':
                    grades = grades + 15

                elif self._h2grades[i] == 'GP' and self._h2grades[i] == 'B':
                    grades = grades + 8.5

                elif self._h2grades[i] == 'MT' and self._h2grades[i] == 'C':
                    grades = grades + 10

                else:
                    pass
            #[1]rebase
            return (grades*(7/8))

        #[0] did not use super().__repr__()
        def __repr__(self):
            return(f"<{self._student_id}>, 3H2: <{self._h2_grades}>, GP: <{self._gp_grade}>, MT: <{self._mt_grade}>")

        #[0] not able to test compute_uas, need to initialize it first
        #print(Student3H2GP_MT.compute_uas())

    #Task 1.3
    class Student3H2GP_MT_h1content():
        def __init__(self,h1content_grade):
            #[0] did not call super() to initialise
            #[0] ( either here or in Student3H2GP_MT_H1content class )
               # did not indicate private attribute by using __
            self._h1content_grade = h1content_grade

        def get_h1content_grade(self):#[1]getter and setter pair
            return (self._h1content_grade)

        def set_h1content_grade(self,h1content_grade):
            self._h1content_grade = h1content_grade

        def compute_uas(self):
            #[0] did not call super() to access parent's compute_uas and h2gradetable and rebase
            grades = 0

            for i in self._h2grades:
                if h2grades[i] == 'A':
                    grades = grades + 20

                elif self._h2grades[i] == 'B':
                    grades = grades + 17.5

                elif self._h2grades[i] == 'C':
                    grades = grades + 15

                elif self._h2grades[i] == 'GP' and self._h2grades[i] == 'B':
                    grades = grades + 8.5

                elif self._h2grades[i] == 'H1' and self._h2grades[i] == 'A':
                    grades = grades + 10

                else:
                    pass

            return (grades * (7/8))

        #[0] did not use super().__repr__()
        def __repr__(self):
            (f"<{self._student_id}>, 3H2: <{self._h2_grades}>, GP: <{self._gp_grade}>, H1 content: <{self._h1content_grade}>"

    class Student3H2GP_MT_H1content():
        def __init__(self,mt_grade,h1content_grade):
            #[0] did not call super() to initialise
            self._mt_grade = h1content_grade
            self._h1content_grade = h1content_grade

        #[2]getter and setter pairs
        def get_mt_grade(self):
            return (self._mt_grade)

        def set_mt_grade(self,mt_grade):
            self._mt_grade = mt_grade

        def get_h1content_grade(self):
            return (self._h1_content)

        def set_h1content_grade(self,h1_content):
            self._h1_content = h1_content

        #[0] did not call super() to access parent's compute_uas and h2gradetable and rebase
        def compute_uas(self):
            grades = 0

            for i in self._h2grades:
                if h2grades[i] == 'A':
                    grades = grades + 20

                elif self._h2grades[i] == 'B':
                    grades = grades + 17.5

                elif self._h2grades[i] == 'C':
                    grades = grades + 15

                elif self._h2grades[i] == 'GP' and self._h2grades[i] == 'B':
                    grades = grades + 8.5

                elif self._h2grades[i] == 'H1' and self._h2grades[i] == 'A':
                    grades = grades + 10

                else:
                    pass

            return (grades * (7/8))

        #[0] did not use super().__repr__()
        def __repr__(self):
            (f"<{self._student_id}>, 3H2: <{self._h2_grades}>, GP: <{self._gp_grade}>, H1 Content: <{self._h1content_grade}>"
# Out:
#   File "<ipython-input-24-a1aebe127335>", line 30
#     'GP': '[]''
#         ^
# SyntaxError: invalid syntax

# %%
#Task 1.4

class Student():
    #[1] correct constructor and initialisation
    def __init__(self,student_id,h2_grades,gp_grade,mt_grade,h1content_grade):
        self._student_id = student_id
        self._h2grades = h2grades
        self._gp_grade = gp_grade
        self._mt_grade = h1content_grade
        self._h1content_grade = h1content_grade

    def compute_max_uas(self):
        #[0] did not initialise any 2, [1] add one more mark if all 4 types of students initialised
        #[0] did not return max of 4 scores
        return (Student3H2GP().compute_uas(self))

# %%
  def get_h2grade_table(h2_grades):  #dict
        grades_dict = {'Subject1' }
        for i in h2_grades:
            grades_dict.append(h2grades[i])
        return grades_dict

get_h2grade_table(['A','A','B'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-f96181d8d381> in <module>()
#       5       return grades_dict
#       6
# ----> 7 get_h2grade_table(['A','A','B'])
#
# <ipython-input-10-f96181d8d381> in get_h2grade_table(h2_grades)
#       2       grades_dict = {'Subject1' }
#       3       for i in h2_grades:
# ----> 4           grades_dict.append(h2grades[i])
#       5       return grades_dict
#       6
#
# AttributeError: 'set' object has no attribute 'append'

# %%
dictionary = {'Apple': 'A',
              'Banana':'B'
             }
for i in dictionary:
    print(dictionary[i])

append.dictionary ('Cat','C')
print(dictionary)
# Out:
# A
# B
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-64b0e15993cf> in <module>()
#       5     print(dictionary[i])
#       6
# ----> 7 append.dictionary ('Cat','C')
#       8 print(dictionary)
#
# NameError: name 'append' is not defined

# %%
        self._mt_grade = mt_grade

    def Student3H2GP_MT_H1content(self,h1content_grade):
        self._h1content_grade = h1content_grade
        self._mt_grade = mt_grade #??

    def Student3H2GP_H1content(self,h1content_grade)
        self._h1content_grade = h1content_grade #??
