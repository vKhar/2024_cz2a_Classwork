# %% [markdown]
# Task 1.1: 8
#
# Task 1.2: 6
#
# Task 1.3: 5
#
# Task 1.4: 0
#
# Total: 19

# %%
#Task 1.1

class Student3H2GP():
    #[1]implement h2_grade_table as attribute and get_h2grade_table() function
    h2grade_table = {"A":20, "B":17.5, "C":15, "D":12.5, "E":10, "S":5, "U":0}

    def __init__(self, student_id, h2grades, gp_grade):
        #[1]indicate private attribute by using __
        self.__student_id = student_id
        self.__h2grades = h2grades
        self.__gp_grade = gp_grade

    #[3] getter and setter pairs
    def get_student_id(self):
        return self.__student_id

    def set_student_id(self, student_id):
        self.__student_id = student_id

    def get_h2grades(self):
        return self.__h2grades

    def set_h2grades(self, h2grades):
        self.__h2grade_table = h2grades

    def get_gp_grades(self):
        return self.__gp_grade

    def set_gp_grades(self, gp_grade):
        self.__gp_grade = gp_grade

    def get_h2grade_table(self):
        return h2grade_table

    def compute_uas(self):
        #[0] did not access self.__h2 grade table to compute UAS
        #[1]correct computation of UAS
        uas = []
        for grade in self.__h2grades:
            uas.append(h2grade_table[grade])
        uas.append((h2grade_table[self.__gp_grade])/2)
        return sum(uas)

    def __repr__(self):#[1]return correct string
        return f"{self.__student_id}, 3H2: {self.__h2grades}, GP: {self.__gp_grade}"

#[1]initialised AND print object
result = Student3H2GP('1001', ['A', 'B', 'C'], 'B')
print(result)
# Out:
# 1001, 3H2: ['A', 'B', 'C'], GP: B

# %%
#Task 1.2

class Student3H2GP_MT(Student3H2GP):
    def __init__(self, student_id, h2grades, gp_grade, mt_grade):
        #[1]call super() to initialise
        super().__init__(student_id, h2grades, gp_grade)
        #[1]indicate private attribute by using __
        self.__mt_grade = mt_grade

    def get_mt_grade(self):#[1]getter and setter pair
        return self.__mt_grade

    def set_mt_grade(self, mt_grade):
        self.__mt_grade = mt_grade

    def compute_uas(self):
        #[0] did not call super() to access parent's compute_uas and h2gradetable
        uas = []
        for grade in [get_h2grades()]:
            uas.append(h2grade_table[grade])
        uas.append((h2grade_table[get_gp_grade()])/2)
        uas.append((h2grade_table[self.__mt_grade])/2)
        #[1]rebase
        return (sum(uas) * (7/8))

    #[0] did not use super().__repr__()
    def __repr__(self):
        return f"{get_student_id()}, 3H2: {get_h2grades()}, GP: {get_gp_grade()}, MT: {self.__mt_grade}"

#[1] initialize and print object
result2 = Student3H2GP_MT('1001', ['A', 'B', 'C'], 'B', 'C')

print(result2)
#[1]test compute_uas
result2.compute_uas()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-ab1a5fe87596> in <module>()
#      25 result2 = Student3H2GP_MT('1001', ['A', 'B', 'C'], 'B', 'C')
#      26
# ---> 27 print(result2)
#      28
#      29 result2.compute_uas()
#
# <ipython-input-64-ab1a5fe87596> in __repr__(self)
#      21
#      22     def __repr__(self):
# ---> 23         return f"{get_student_id()}, 3H2: {get_h2grades()}, GP: {get_gp_grade()}, MT: {self.__mt_grade}"
#      24
#      25 result2 = Student3H2GP_MT('1001', ['A', 'B', 'C'], 'B', 'C')
#
# NameError: name 'get_student_id' is not defined

# %%
#Task 1.3

class Student3H2GP_H1content(Student3H2GP):
    def __init__(self, student_id, h2grades, gp_grade, h1content_grade):
        #[1]call super() to initialise
        super().__init__(student_id, h2grades, gp_grade)
        #[1] ( either here or in Student3H2GP_MT_H1content class )
               #indicate private attribute by using __
        self.__h1content_grade = h1content_grade

    def get_h1content_grade(self):#[1]getter and setter pair
        return self.__h1content_grade

    def set_h1content_grade(self, h1content_grade):
        self.__h1content_grade = h1content_grade

    def compute_uas(self):
        #[0] did not call super() to access parent's compute_uas and h2gradetable and rebase
        uas = []
        for grade in [get_h2grades()]:
            uas.append(h2grade_table[grade])
        uas.append((h2grade_table[get_gp_grade()])/2)
        uas.append((h2grade_table[self.__h1content_grade])/2)
        return (sum(uas) * (7/8))

    #[0] did not use super().__repr__()
    def __repr__(self):
        return f"{get_student_id()}, 3H2: {get_h2grades()}, GP: {get_gp_grade()}, H1 Content: {self.__h1content_grade}"

# %%
#Task 1.4 - actual Task 1.4 not done
#this is Task 1.3 still

class Student3H2GP_MT_H1content(Student3H2GP):
    def __init__(self, student_id, h2grades, gp_grade, mt_grade, h1content_grade):
        #[1]call super() to initialise
        super().__init__(student_id, h2grades, gp_grade)
        self.__mt_grade = mt_grade
        self.__h1content_grade = h1content_grade

    def get_mt_grade(self):#[2]getter and setter pairs
        return self.__mt_grade

    def set_mt_grade(self, mt_grade):
        self.__mt_grade = mt_grade

    def get_h1content_grade(self):
        return self.__h1content_grade

    def set_h1content_grade(self, h1content_grade):
        self.__h1content_grade = h1content_grade

    def compute_uas(self):
        #[0] did not call super() to access parent's compute_uas and h2gradetable and rebase
        uas = []
        for grade in [get_h2grades()]:
            uas.append(h2grade_table[grade])
        uas.append((h2grade_table[get_gp_grade()])/2)
        uas.append((h2grade_table[self.__h1content_grade])/2)
        uas.append((h2grade_table[self.__mt_grade])/2)
        return (sum(uas) * (7/9))

    #[0] did not use super().__repr__()
    def __repr__(self):
        return f"{get_student_id()}, 3H2: {get_h2grades()}, GP: {get_gp_grade()}, H1 Content: {self.__h1content_grade}"
