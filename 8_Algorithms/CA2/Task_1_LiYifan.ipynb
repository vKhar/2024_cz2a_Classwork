# %% [markdown]
# Task 1.1: 6
#
# Task 1.2: 3
#
# Task 1.3: 4
#
# Task 1.4: 1
#
# Total: 14

# %%
#task 1.1

#class for students
class Student3H2GP:
#     h2grade_table( A: 20,
#                   B: 17.5,
#                   C: 15,
#                   D: 12.5,
#                   E: 10,
#                   s: 5,
#                   U: 0)
    #constructor
    def __init__(self, student, h2, gp):
        #[1]indicate private attribute by using __
        self.__student_id = student
        self.__h2grades = h2
        self.__gp_grade = gp
        #[0] did not implement h2_grade_table as attribute and get_h2grade_table() function

    #[1]return correct string
    def __repr__(self):
        return f"student_id: {self.__student_id}, 3H2: {self.__h2grades}, GP: {self.__gp_grade}"
    #[3] getter and setter pairs
    #getter
    def get_student_id(self):
        return self.__student_id

    def get_h2grades(self):
        return self.__h2grades

    def get_gp_grade(self):
        return self.__gp_grade
    #setter

    def set_student_id(self, new_student):
        self.__student_id = new_student

    def set_h2grades(self, new_list):
        self.__h2grades = new_list

    def set_gp_grade(self, new_gp):
        self.__gp_grade = new_gp

    #other method
    def compute_uas(self):
        #[0] did not access self.__h2 grade table to compute UAS
        #[0] did not correct computation of UAS
        pass

# %%
#task 1.1
#[1]initialised AND print object
stu1 = Student3H2GP(1001, ['A','B','C'], 'B')
print(stu1)
# print(stu1.get_gp_grade())
# Out:
# 1001, 3H2: ['A', 'B', 'C'], GP: B
# B

# %%
#task 1.2

class Student3H2GP_MT(Student3H2GP):
    def __init__(self, student, h2, gp, mt):
        #[0] did not call super() to initialise
        self.__student_id = student
        self.__h2grades = h2
        self.__gp_grade = gp
        #[1]indicate private attribute by using __
        self.__mt_grade = mt

    def __repr__(self): #[0] did not use super().__repr__()
        return f"student_id: {self.__student_id}, 3H2: {self.__h2grades}, GP: {self.__gp_grade}, MT: {self.__mt_grade}"

    def get_mt_grade(self):#[1]getter and setter
        return self.__mt_grade

    def set_mt_grade(self, grade):
        self.__mt_grade = grade

# %%
#task 1.2
#[1] initialize and print object
stu2 = Student3H2GP_MT(1001, ['A', 'B', 'c'], 'B', 'C')
print(stu2)

# print(stu2.get_mt_grade())
# Out:
# student_id:1001, 3H2: ['A', 'B', 'c'], GP: B, MT: C

# %%
#task 1.3

class Student3H2GP_H1content(Student3H2GP):
    def __init__(self, student, h2, gp, h1):
        #[0] did not call super() to initialise
        self.__student_id = student
        self.__h2grades = h2
        self.__gp_grade = gp
        #[1] ( either here or in Student3H2GP_MT_H1content class )
               #indicate private attribute by using __
        self.__h1content_grade = h1

    #[0] did not use super().__repr__()
    def __repr__(self):
        return f"student_id: {self.__student_id}, 3H2: {self.__h2grades}, GP: {self.__gp_grade}, H1 Content: {self.__h1content_grade}"

    def get_h1content_grade(self):#[1]getter and setter
        return self.__h1content_grade

    def set_h1content_grade(self, grade):
        self.__h1content_grade = grade

class Student3H2GP_MT_H1content(Student3H2GP):
    #[0] did not call super() to initialise
    def __init__(self, student, h2, gp, mt, h1):
        self.__student_id = student
        self.__h2grades = h2
        self.__gp_grade = gp
        self.__h1content_grade = h1
        self.__mt_grade = mt

    #[0] did not use super().__repr__()
    def __repr__ (self):
        return f"student_id: {self.__student_id}, 3H2: {self.__h2grades}, GP: {self.__gp_grade}, MT: {self.__mt_grade}, H1 Content: {self.__h1content_grade}"

    def get_mt_grade(self): #[2]getter and setter pairs
        return self.__mt_grade

    def get_h1content_grade(self):
        return self.__h1content_grade

    def set_mt_grade(self,value):
        self.__mt_grade = value

    def set_h1content_grade(self, grade):
        self.__h1content_grade = grade

# %%
#task1.4

class Student:
     #[1] correct constructor and initialisation
    def __init__(self, student, h2, gp, h1, mt):
        self.__student_id = student
        self.__h2grades = h2
        self.__gp_grade = gp
        self.__h1content_grade = h1
        self.__mt_grade = mt
    def max_subject(self):
        pass
