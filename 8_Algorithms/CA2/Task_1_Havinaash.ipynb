# %% [markdown]
# Task 1.1: 3
#
# Task 1.2: 0
#
# Task 1.3: 0
#
# Task 1.4: 4
#
# Total: 7

# %%
#Task 1.1
class Student3H2GP:
    def __init__(self, student_id, h2grades, gp_grade):
        self.student_id = student_id #[0] did not indicate private attribute by using __
        self.h2grades = h2grades
        self.gp_grade = gp_grade
        #[0]did not implement dictionary as attribute

    def __get_student_id__(self): #[0.5] getter; should not have __ prepended
        return self.student_id
    def __set_student_id__(self, student_id): #wrong setter function
        student_id = input("Enter student id: ")
    def __get_h2grades__(self): #[0.5] getter
        return self.h2grades
    def __set_h2grades__(self, h2grades):
        h2grades = input("Enter your 3H2 grades: ")
    def __get_gp_grade__(self): #[0.5] getter
        return self.gp_grades
    def __set_gp_grade__(self, gp_grade):
        gp_grade = input("Enter your GP grade: ")
    def __get_h2grade_table__(self): #[0.5] get_h2grade_table() function
        grade_table = {
            'A':20,
            'B':17.5,
            'C':15,
            'D':12.5,
            'E':10,
            'S':5,
            'U':0,
        }
        return grade_table
        
    def __compute_uas__(self):
        def __get_h2grade_table__(self):
            grade_table = {
                'A':20,
                'B':17.5,
                'C':15,
                'D':12.5,
                'E':10,
                'S':5,
                'U':0,
            }
            return grade_table
        #[0] not able to access self.__h2 grade table to compute UAS
        #[0] correct computation of UAS
        sum = 0
        for grade in self.h2grades:
            #'dict' object has no attribute 'key'
            if grade == grade_table.key():
                sum += grade_table.get()
        # grade_table.keys() returns a dict_keys object: 
        # A view object is returned by the function which consists of a list of all the keys in the dictionary. 
        if gp_grade == grade_table.key():
            sum += 0.5*grade_table.get()
        return sum
    
    def __repr__(self): #[1]return correct string
        return f"<{self.student_id}>, 3H2: <{self.h2grades}>, GP: <{self.gp_grade}>"

# %%
a = Student3H2GP('1001', ['A', 'B', 'C'], 'B') #[0]initialised but did not print
a.__compute_uas__()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-9cdefe30d19d> in <module>()
#       1 a = Student3H2GP('1001', ['A', 'B', 'C'], 'B')
# ----> 2 a.__compute_uas__()
#
# <ipython-input-49-0a2f17c5e65b> in __compute_uas__(self)
#      43         sum = 0
#      44         for grade in self.h2grades:
# ---> 45             if grade == grade_table.key():
#      46                 sum += grade_table.get()
#      47         if gp_grade == grade_table.key():
#
# NameError: name 'grade_table' is not defined

# %%
#Task 1.2
class Student3H2GP_MT(Student3H2GP):
    def __init__(self, student_id, h2grades, gp_grade, mt_grade):
         #[0] did not call super() to initialise properly
        __init__.super()
        self.mt_grade = mt_grade #[0] did not indicate private attribute by using __
    
    def __get_mt_grade__(self): # should return self.mt_grade
        return mt_grade
    def __set_mt_grade__(self, mt_grade):
        mt_grade = input("Enter your MT grade here: ")
    def __compute_uas__(self):
        #[0] did not call super() to access parent's compute_uas and h2gradetable
        def __get_h2grade_table__(self):
            grade_table = {
                'A':20,
                'B':17.5,
                'C':15,
                'D':12.5,
                'E':10,
                'S':5,
                'U':0,
            }
            return grade_table
        sum = 0
        for grade in self.h2grades:
            if grade == grade_table.key():
                sum += grade_table.get()
        if gp_grade == grade_table.key():
            sum += 0.5*grade_table.get()
        if mt_grade == grade_table.key():
            sum += 0.5*grade_table.get()
        sum = (sum / 80) * 70
        return sum
    def __repr__(self): #[0] did not use super().__repr__()
        return f"<student_id>, 3H2: <h2_grades>, GP: <gp_grade>, MT: <mt_grade>"

# %%
#[0] did not initialize and print
#[0] did not test compute_uas

# %%
#Task 1.3
class Student3H2GP_H1content(Student3H2GP):
    def __init__(self, student_id, h2grades, gp_grade, h1content_grade):
        #[0] did not call super() to initialise correctly
        __init__.super()
        #[0] ( either here or in Student3H2GP_MT_H1content class )
               # did not indicate private attribute by using __
        self.h1content_grade = h1content_grade
    def __get_h1content_grade__(self): #[0] should return self.h1content_grade
        return h1content_grade
    def __set_h1content_grade__(self, new_h1contentgrade):
        new_h1content_grade = input("Enter your H1 grade here: ")
    def __compute_uas__(self):
        #[0] did not call super() to access parent's compute_uas and h2gradetable and rebase
        def __get_h2grade_table__(self):
            grade_table = {
                'A':20,
                'B':17.5,
                'C':15,
                'D':12.5,
                'E':10,
                'S':5,
                'U':0,
            }
            return grade_table
        sum = 0
        for grade in self.h2grades:
            if grade == grade_table.key():
                sum += grade_table.get()
        if gp_grade == grade_table.key():
            sum += 0.5*grade_table.get()
        if h1content_grade == grade_table.key():
            sum += 0.5*grade_table.get()
        sum = (sum / 80) * 70
        return sum
    def __repr__(self):#[0] did not use super().__repr__()
        return f"<student_id>, 3H2: <h2_grades>, GP: <gp_grade>, H1 Content: <h1content_grade>"
    
class Student3H2GP_MT_H1content(Student3H2GP):
    def __init__(self, student_id, h2grades, gp_grade, mt_grade):
        #[0] did not call super() to initialise
        __init__.super()
        self.mt_grade = mt_grade
    def __get_mt_grade__(self): #[0] should return self.mt_grade
        return mt_grade
    def __set_mt_grade__(self, mt_grade):
        mt_grade = input("Enter your MT grade here: ")
    def __get_h1content_grade__(self):
        return h1content_grade
    def __set_h1content_grade__(self, new_h1contentgrade):
        new_h1content_grade = input("Enter your H1 grade here: ")
    def __compute_uas__(self):
        #[0] did not call super() to access parent's compute_uas and h2gradetable and rebase
        def __get_h2grade_table__(self):
            grade_table = {
                'A':20,
                'B':17.5,
                'C':15,
                'D':12.5,
                'E':10,
                'S':5,
                'U':0,
            }
            return grade_table
        sum = 0
        for grade in self.h2grades:
            if grade == grade_table.key():
                sum += grade_table.get()
        if gp_grade == grade_table.key():
            sum += 0.5*grade_table.get()
        if mt_grade == grade_table.key():
            sum += 0.5*grade_table.get()
        sum = (sum / 90) * 70
        return sum
    def __repr__(self): #[0] did not use super().__repr__()
        return f"<student_id>, 3H2: <h2_grades>, GP: <gp_grade>, MT: <mt_grade>, H1 Content: <h1content_grade>"

# %%
#task 1.4
class Student:
    def __init__(self, student_id, h2grades, gp_grade, mt_grade, h1content_grade):
        #[1] correct constructor
        self.student_id = student_id
        self.h2grades = h2grades
        self.gp_grade = gp_grade
        self.mt_grade = mt_grade
        self.h1content_grade = h1content_grade
    def __compute_max_uas__(self):
        highest = float("-inf")
        #[1]initialise any 2, [1] add one more mark if all 4 types of students initialised
        uas_list = [Student3H2GP_MT_H1content.__compute_uas__(), 
                    Student3H2GP_H1content.__compute_uas__(), 
                    Student3H2GP_MT.__compute_uas__(),
                    Student3H2GP.__compute_uas__()]
        for i in uas_list:
            if i > highest:
                highest = i
        return highest #[1]return max of 4 scores

# %%
#[0] did not instantiate Student Object
#[0] did not compute max UAS correctly
