# %% [markdown]
# Task 1.1: 6.5
#
# Task 1.2: 2
#
# Task 1.3: 1
#
# Task 1.4: 2
#
# Total: 11.5

# %%
#Task 1.1
class Student3H2GP:
    def __init__ (self, student_id, h2grades, gp_grade):
        self.__student_id = student_id #[1]indicate private attribute by using __
        self.__h2grades = h2grades
        self.__gp_grade = gp_grade
        #[0] no h2grade_table dictionary

    def __repr__(self): #[1]return correct string
        return f"<{self.__student_id}, 3H2: {self.__h2grades}, GP: {self.__gp_grade}>"

    #Getters
    def get_student_id(self):#[3] getter and setter pairs
        return self.__student_id
    def get_h2grades(self):
        return self.__h2grades
    def get_gp_grade(self):
        return self.__gp_grade

    #Setters
    def set_h2grades(self, value1):
        self.__h2grades = value1
    def set_student_id(self, value2):
        self.__student_id = value2
    def set_gp_grade(self, value3):
        self.__gp_grade = value3

    # [0.5] get_h2grade_table() function; incomplete dictionary though
    def get_h2grade_table(self):
        h2grade_table = {
            "A": 20,
            "B": 17.5,
            "C": 15,
        }
        return h2gradestable

    def compute_uas(self):
        #[0] did not access the h2 grade table to compute UAS
        #[0] wrong computation of UAS
        for self.__h2grades

        h2_gradevalue1 + h2_gradevalue2 + h2_gradevalue3 + h1_gradevalue

# %%
x = Student3H2GP('1001', ['A','B','C'], 'B')
print(x.get_student_id())
print(x.get_h2grades())
print(x.get_gp_grade())
print(x) #[1]initialise AND print

x.set_h2grades(['A','D'])
print(x.get_h2grades())
x.set_student_id('1233')
print(x.get_student_id())
x.set_gp_grade('C')
print(x.get_gp_grade())
# Out:
# 1001
# ['A', 'B', 'C']
# B
# <1001, 3H2: ['A', 'B', 'C'], GP: B>
# ['A', 'D']
# 1233
# C

# %%
#Task 1.2
class Student3H2GP_MT: #[-1] did not inherit from super class
    def __init__ (self, student_id, h2_grades, gp_grade, mt_grade):
        self.__student_id = student_id #[0] did not call super() to initialise
        self.__h2_grades = h2_grades
        self.__gp_grade = gp_grade
        self.__mt_grade = mt_grade #[1]indicate private attribute by using __

    def __repr__(self): #[0] did not call super for partial __repr__
        return f"<student_id:{self.__student_id}, 3H2: {self.__h2_grades}, GP: {self.__gp_grade}, MT: {self.__mt_grade}>"

    #Getters
    def get_student_id(self):
        return self.__student_id
    def get_h2_grades(self):
        return self.__h2_grades
    def get_gp_grade(self):
        return self.__gp_grade
    def get_mt_grade(self): #[1]getter and setter
        return self.__mt_grade

    #Setters
    def set_h2_grades(self, value1):
        self.__h2_grades = value1
    def set_student_id(self, value2):
        self.__student_id = value2
    def set_gp_grade(self, value3):
        self.__gp_grade = value3
    def set_mt_grade(self, value4):
        self.__mt_grade = value4


    def get_h2grade_table(self):
        h2grade_table = {
            "A": 20,
            "B": 17.5,
            "C": 15,
        }
        return h2grade_table

    # did not implement compute_uas

# %%
x = Student3H2GP_MT('1001', ['A','B','C'], 'B', 'C')
print(x.get_student_id())
print(x.get_h2_grades())
print(x.get_gp_grade())
print(x.get_mt_grade())
print(x) #[1] initialize and print
#[0] did not test compute_uas

x.set_h2_grades(['A','D'])
print(x.get_h2_grades())
x.set_student_id('1233')
print(x.get_student_id())
x.set_gp_grade('C')
print(x.get_gp_grade())
x.set_mt_grade('D')
print(x.get_mt_grade())
# Out:
# 1001
# ['A', 'B', 'C']
# B
# C
# <student_id:1001, 3H2: ['A', 'B', 'C'], GP: B, MT: C>
# ['A', 'D']
# 1233
# C
# D

# %%
#Task 1.3
# did not implement Student3H2GP_H1content(Student3H2GP)
# for Student3H2GP_MT_H1content, did not inherit from Student3H2GP
class Student3H2GP_MT_H1content: # did not include H1 content in constructor
    def __init__ (self, student_id, h2_grades, gp_grade, mt_grade):
        self.__student_id = student_id #[0] did not call super() to initialise
        self.__h2_grades = h2_grades
        self.__gp_grade = gp_grade
        self.__mt_grade = mt_grade

    def __repr__(self): #[0] did not use super().__repr__()
        return f"<student_id:{self.__student_id}, 3H2: {self.__h2_grades}, GP: {self.__gp_grade}, MT: {self.__mt_grade}>"

    #Getters
    def get_student_id(self):
        return self.__student_id
    def get_h2_grades(self):
        return self.__h2_grades
    def get_gp_grade(self):
        return self.__gp_grade
    def get_mt_grade(self): #[1] getter and setter
        return self.__mt_grade

    #Setters
    def set_h2_grades(self, value1):
        self.__h2_grades = value1
    def set_student_id(self, value2):
        self.__student_id = value2
    def set_gp_grade(self, value3):
        self.__gp_grade = value3
    def set_mt_grade(self, value4):
        self.__mt_grade = value4


    def get_h2grade_table(self):
        h2grade_table = {
            "A": 20,
            "B": 17.5,
            "C": 15,
        }
        return h2grade_table

# %%
#Task 1.4
class Student:
    #[1] correct constructor
    def __init__ (self, student_id, h2_grades, gp_grade, mt_grade, h1content_grade):
        self.__student_id = student_id
        self.__h2_grades = h2_grades
        self.__gp_grade = gp_grade
        self.__mt_grade = mt_grade
        self.__h1content_grade = h1content_grade

    def __repr__(self):
        return f"<student_id:{self.__student_id}, 3H2: {self.__h2_grades}, GP: {self.__gp_grade}, MT: {self.__mt_grade}, H1 Content: {self.__h1content_grade}>"

    #Getters
    def get_student_id(self):
        return self.__student_id
    def get_h2_grades(self):
        return self.__h2_grades
    def get_gp_grade(self):
        return self.__gp_grade
    def get_mt_grade(self):
        return self.__mt_grade
    def get_h1content_grade (self):
        return self.__h1content_grade

    #Setters
    def set_h2_grades(self, value1):
        self.__h2_grades = value1
    def set_student_id(self, value2):
        self.__student_id = value2
    def set_gp_grade(self, value3):
        self.__gp_grade = value3
    def set_mt_grade(self, value4):
        self.__mt_grade = value4
    def set_h1content_grade (self, value5):
        set_h1content_grade = value5


    def get_h2grade_table(self):
        h2grade_table = {
            "A": 20,
            "B": 17.5,
            "C": 15,
        }
        return h2grade_table

    # did not implement compute_max_uas

# %%
x = Student('1001', ['A','B','C'], 'B', 'C', 'A') #[1]instantiate Student Object
print(x.get_student_id())
print(x.get_h2_grades())
print(x.get_gp_grade())
print(x.get_mt_grade())
print(x.get_h1content_grade())
print(x)

x.set_h2_grades(['A','D'])
print(x.get_h2_grades())
x.set_student_id('1233')
print(x.get_student_id())
x.set_gp_grade('C')
print(x.get_gp_grade())
x.set_mt_grade('D')
print(x.get_mt_grade())
x.set_h1content_grade('B')
print(x.get_h1content_grade())
# Out:
# 1001
# ['A', 'B', 'C']
# B
# C
# A
# <student_id:1001, 3H2: ['A', 'B', 'C'], GP: B, MT: C, H1 Content: A>
# ['A', 'D']
# 1233
# C
# D
# A
