# %%
import random

classlist = ["Alexzander", "Yew Zhi", "Constance", "Evan", "Faldo", "Gurupreeth", "Havinaash", "Henry", "Ian", "Javier", "Jia Fang", "Kah Xiang", "Kaylee", "Krishna", "Yifan", "Zeyuan", "Ray Teng", "Aditya", "Sanam", "Shuban", "Sophie", "Swetha", "Tianxiong", "Trina", "Ziheng", "Widjaya",
"Zachary"]

for i in range(5):
  index = random.randint(0, len(classlist)-1)
  print(classlist[index])
# Out:
# Tianxiong
# Ian
# Aditya
# Aditya
# Tianxiong
