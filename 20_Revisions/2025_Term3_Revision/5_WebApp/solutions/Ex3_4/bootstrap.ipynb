# %%
# %run flask_server.py
# Out:
#  * Serving Flask app 'flask_server' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [13/Aug/2025 11:53:40] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Aug/2025 11:54:18] "POST / HTTP/1.1" 302 -
# 127.0.0.1 - - [13/Aug/2025 11:54:18] "GET /start HTTP/1.1" 200 -
# true
# 127.0.0.1 - - [13/Aug/2025 11:54:37] "POST /guess HTTP/1.1" 302 -
# 127.0.0.1 - - [13/Aug/2025 11:54:37] "GET /start HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Aug/2025 11:54:50] "POST /guess HTTP/1.1" 302 -
# 127.0.0.1 - - [13/Aug/2025 11:54:50] "GET /start HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Aug/2025 11:54:56] "POST /guess HTTP/1.1" 302 -
# 127.0.0.1 - - [13/Aug/2025 11:54:56] "GET /start HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Aug/2025 11:55:00] "POST /guess HTTP/1.1" 302 -
# ...
